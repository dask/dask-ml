# %%
import numpy as np
from sklearn import datasets
from sklearn import metrics
from sklearn import model_selection
from sklearn import preprocessing

import tensorflow as tf

# %%
boston = datasets.load_boston()
x, y = boston.data, boston.target

x_train, x_test, y_train, y_test = model_selection.train_test_split(
  x, y, test_size=0.2, random_state=42)

# Scale data (training set) to 0 mean and unit standard deviation.
scaler = preprocessing.StandardScaler()
x_train = scaler.fit_transform(x_train).astype(np.float32)

# %%
# Build 2 layer fully connected DNN with 10, 10 units respectively.
feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(
  x_train)
regressor = tf.contrib.learn.DNNRegressor(
  feature_columns=feature_columns, hidden_units=[10, 10])
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x116704a90>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': None}
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/hz/f43khqfn7b1b1g8z_z6y3bsw0000gp/T/tmps_1hi66m

# %%
# Fit
regressor.fit(x_train, y_train, steps=5000, batch_size=1)

# Transform
x_transformed = scaler.transform(x_test)

# Predict and score
y_predicted = list(regressor.predict(x_transformed, as_iterable=True))
score = metrics.mean_squared_error(y_predicted, y_test)

print('MSE: {0:f}'.format(score))
# Out:
# WARNING:tensorflow:From <ipython-input-17-766533a0e0da>:2: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-17-766533a0e0da>:2: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-17-766533a0e0da>:2: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /Users/taugspurger/Envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# /Users/taugspurger/Envs/py3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/hz/f43khqfn7b1b1g8z_z6y3bsw0000gp/T/tmps_1hi66m/model.ckpt.
# INFO:tensorflow:loss = 424.25, step = 1
# INFO:tensorflow:global_step/sec: 1464.3
# INFO:tensorflow:loss = 36.0381, step = 101 (0.069 sec)
# INFO:tensorflow:global_step/sec: 1476.72
# INFO:tensorflow:loss = 2.61193, step = 201 (0.068 sec)
# INFO:tensorflow:global_step/sec: 1392.99
# INFO:tensorflow:loss = 3.0287, step = 301 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1520.68
# INFO:tensorflow:loss = 27.8177, step = 401 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1462.39
# INFO:tensorflow:loss = 3.17875, step = 501 (0.068 sec)
# INFO:tensorflow:global_step/sec: 1449.24
# INFO:tensorflow:loss = 3.43134, step = 601 (0.069 sec)
# INFO:tensorflow:global_step/sec: 1514.28
# INFO:tensorflow:loss = 18.1307, step = 701 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1516.55
# INFO:tensorflow:loss = 1.99195, step = 801 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1487.41
# INFO:tensorflow:loss = 7.23216, step = 901 (0.067 sec)
# INFO:tensorflow:global_step/sec: 1509.57
# INFO:tensorflow:loss = 2.51652, step = 1001 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1518.55
# INFO:tensorflow:loss = 13.9048, step = 1101 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1492.32
# INFO:tensorflow:loss = 2.39383, step = 1201 (0.067 sec)
# INFO:tensorflow:global_step/sec: 1486.24
# INFO:tensorflow:loss = 7.92061, step = 1301 (0.068 sec)
# INFO:tensorflow:global_step/sec: 1489.49
# INFO:tensorflow:loss = 14.5363, step = 1401 (0.067 sec)
# INFO:tensorflow:global_step/sec: 1538.81
# INFO:tensorflow:loss = 20.3955, step = 1501 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1537.3
# INFO:tensorflow:loss = 0.763657, step = 1601 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1547.31
# INFO:tensorflow:loss = 4.13475, step = 1701 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1527.94
# INFO:tensorflow:loss = 0.0632739, step = 1801 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1510.8
# INFO:tensorflow:loss = 0.292081, step = 1901 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1568.93
# INFO:tensorflow:loss = 0.0283971, step = 2001 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1537.68
# INFO:tensorflow:loss = 5.01053, step = 2101 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1440.79
# INFO:tensorflow:loss = 4.75189, step = 2201 (0.070 sec)
# INFO:tensorflow:global_step/sec: 1548.78
# INFO:tensorflow:loss = 6.92671, step = 2301 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1566.54
# INFO:tensorflow:loss = 20.462, step = 2401 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1568.04
# INFO:tensorflow:loss = 366.371, step = 2501 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1558.18
# INFO:tensorflow:loss = 0.113168, step = 2601 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1487.46
# INFO:tensorflow:loss = 11.5876, step = 2701 (0.067 sec)
# INFO:tensorflow:global_step/sec: 1494.17
# INFO:tensorflow:loss = 3.3902, step = 2801 (0.067 sec)
# INFO:tensorflow:global_step/sec: 1542.17
# INFO:tensorflow:loss = 0.252894, step = 2901 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1539.05
# INFO:tensorflow:loss = 4.0299, step = 3001 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1459.75
# INFO:tensorflow:loss = 46.9626, step = 3101 (0.069 sec)
# INFO:tensorflow:global_step/sec: 1543.41
# INFO:tensorflow:loss = 20.4318, step = 3201 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1475.29
# INFO:tensorflow:loss = 3.63323, step = 3301 (0.068 sec)
# INFO:tensorflow:global_step/sec: 1498.62
# INFO:tensorflow:loss = 0.0383738, step = 3401 (0.067 sec)
# INFO:tensorflow:global_step/sec: 1563.23
# INFO:tensorflow:loss = 10.4082, step = 3501 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1546.39
# INFO:tensorflow:loss = 16.7839, step = 3601 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1522.02
# INFO:tensorflow:loss = 0.998862, step = 3701 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1573.79
# INFO:tensorflow:loss = 7.36487, step = 3801 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1573.37
# INFO:tensorflow:loss = 7.28014, step = 3901 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1551.23
# INFO:tensorflow:loss = 1.19376, step = 4001 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1594.28
# INFO:tensorflow:loss = 0.882182, step = 4101 (0.063 sec)
# INFO:tensorflow:global_step/sec: 1591.04
# INFO:tensorflow:loss = 1.207, step = 4201 (0.063 sec)
# INFO:tensorflow:global_step/sec: 1582.77
# INFO:tensorflow:loss = 38.121, step = 4301 (0.063 sec)
# INFO:tensorflow:global_step/sec: 1538.7
# INFO:tensorflow:loss = 4.94628, step = 4401 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1602.3
# INFO:tensorflow:loss = 1.94923, step = 4501 (0.062 sec)
# INFO:tensorflow:global_step/sec: 1597.73
# INFO:tensorflow:loss = 0.0510742, step = 4601 (0.063 sec)
# INFO:tensorflow:global_step/sec: 1546.74
# INFO:tensorflow:loss = 20.434, step = 4701 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1537.3
# INFO:tensorflow:loss = 2.91961, step = 4801 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1491.23
# INFO:tensorflow:loss = 0.189475, step = 4901 (0.067 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /var/folders/hz/f43khqfn7b1b1g8z_z6y3bsw0000gp/T/tmps_1hi66m/model.ckpt.
# INFO:tensorflow:Loss for final step: 26.3705.
# WARNING:tensorflow:From /Users/taugspurger/Envs/py3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:335: calling DNNRegressor.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_scores, or set `outputs` argument.
# WARNING:tensorflow:From /Users/taugspurger/Envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:733: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Restoring parameters from /var/folders/hz/f43khqfn7b1b1g8z_z6y3bsw0000gp/T/tmps_1hi66m/model.ckpt-5000
# MSE: 12.802166
